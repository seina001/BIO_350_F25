# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
for i in range(30):
    if i == 9:
        print(i+1)
# Out:
# 10

# %%
def NandM_population(N_0, M_0, time, K_N, K_M, d_N, d_M, S):
    #growth model
    #save N_values and M_values into a list
    N_values = [N_0]
    M_values = [M_0]
    #saves inital values to list
    current_N = N_0
    current_M = M_0
    #set current population size
    # N_0 = 5
    # M_0 = 12
    # S = 1
    # d_N = 0.4
    # d_M = 0.6
    # K_N = 400
    # K_M = 1600
    for i in range(time):
        if i == 4:
            current_M = current_M + 100
        current_N = current_N + S * current_N * (1 - (current_N / K_N) - (current_M / K_M)) - d_N * current_N
        current_M = current_M + S * current_M * (1 - (current_M / K_M) - (current_N / K_N)) - d_M * current_M
        current_M = round(current_M, 3)
        M_values.append(current_M)
        current_N = round(current_N, 3)
        N_values.append(current_N)
    return N_values, M_values
#returns the list of population sizes over time

# %%
#run the funtion with 35 days and p = 0.4 with an initial population of 0.01
#def NandM_population(current_N, current_M, time, K_N, K_M, d_N, d_M, S):
Npop,Mpop = NandM_population(12,80, 35, 400, 1600, 0.4, 0.6, 1)
# initial values
print(Npop, Mpop)
# gives the results in a readable format
# Out:
# [12, 18.24, 27.163, 39.372, 55.154, 70.743, 87.427, 104.495, 121.359, 137.567, 152.765, 166.674, 179.097, 189.933, 199.182, 206.933, 213.333, 218.561, 222.798, 226.214, 228.96, 231.163, 232.928, 234.341, 235.473, 236.378, 237.102, 237.682, 238.145, 238.516, 238.813, 239.05, 239.24, 239.392, 239.514, 239.611] [80, 104.352, 132.201, 161.146, 187.155, 299.695, 297.934, 283.798, 260.875, 232.971, 203.263, 174.049, 146.806, 122.35, 101.009, 82.781, 67.461, 54.74, 44.273, 35.719, 28.764, 23.13, 18.579, 14.91, 11.958, 9.585, 7.68, 6.152, 4.926, 3.944, 3.157, 2.527, 2.022, 1.618, 1.295, 1.036]

# %%
# Plot Npop and Mpop over days, each on its own line
days = list(range(36))  # Days from 0 to 35
plt.plot(days, Npop, label='Species N Population', color='blue', marker='o')
plt.plot(days, Mpop, label='Species M Population', color='orange', marker='o')
plt.xlabel('Days')
plt.ylabel('Population')
plt.title('Lotka-Volterra Competition: Population Over Time')
plt.grid()
plt.legend()
plt.show()

# %%
def NandM_population(N_0, M_0, time, K_N, K_M, r_N, r_M, alpha, beta):
    #growth model
    #save N_values and M_values into a list
    N_values = [N_0]
    M_values = [M_0]
    #saves inital values to list
    current_N = N_0
    current_M = M_0
    #set current population size
    # N_0 = 5
    # M_0 = 12
    # S = 1
    # d_N = 0.4
    # d_M = 0.6
    # K_N = 400
    # K_M = 1600
    for i in range(time):
        if i == 14:
            current_N = current_N + 200
        #N_0+1 = N_0 + r_N *N_0 * (1-((N_0+alpha*M_0)/K_N))
        #M_0+1 = M_0 + r_M *M_0 * (1-((M_0+beta*N_0)/K_M))
        current_N = current_N + r_N * current_N * (1 - ((current_N + alpha * current_M) / K_N))
        current_M = current_M + r_M * current_M * (1 - ((current_M + beta * current_N) / K_M))
        current_M = round(current_M, 3)
        M_values.append(current_M)
        current_N = round(current_N, 3)
        N_values.append(current_N)
    return N_values, M_values
#returns the list of population sizes over time

# %%
#run the funtion with 35 days
#def NandM_population(N_0, M_0, time, K_N, K_M, r_N, r_M, alpha, beta):
Npop,Mpop = NandM_population(12,5, 35, 400, 500, 1.2, 1.2, 0.5, 0.9)
# initial values
print(Npop, Mpop)
# gives the results in a readable format
# Out:
# [12, 25.878, 54.509, 109.213, 197.62, 296.824, 345.298, 340.356, 329.639, 319.363, 309.77, 301.311, 294.231, 288.569, 284.207, 188.121, 225.371, 243.53, 253.699, 260.05, 264.178, 266.913, 268.749, 269.993, 270.843, 271.426, 271.827, 272.104, 272.296, 272.428, 272.52, 272.583, 272.628, 272.658, 272.679, 272.694] [5, 10.661, 21.926, 41.911, 70.098, 97.48, 118.946, 140.28, 161.505, 181.3, 198.664, 213.042, 224.367, 232.94, 239.243, 291.751, 295.543, 285.102, 275.912, 269.318, 264.743, 261.589, 259.415, 257.915, 256.879, 256.162, 255.666, 255.322, 255.084, 254.919, 254.805, 254.725, 254.67, 254.632, 254.606, 254.587]

# %%
# Plot Npop and Mpop over days, each on its own line
days = list(range(36))  # Days from 0 to 35
plt.plot(days, Npop, label='Species N Population', color='blue', marker='o')
plt.plot(days, Mpop, label='Species M Population', color='orange', marker='o')
plt.xlabel('Days')
plt.ylabel('Population')
plt.title('Lotka-Volterra Competition: Population Over Time')
plt.grid()
plt.legend()
plt.show()
